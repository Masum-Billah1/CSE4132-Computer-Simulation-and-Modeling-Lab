# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# %%
data = pd.read_csv("in.csv")

# %%
size = int(len(data) * 0.66)
train, test = data[0:size], data[size:len(data)]

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
print(train.head(10))
# Out:
#      Month  Sales(USD)
# 0  2021-01       266.0
# 1  2021-02       145.9
# 2  2021-03       183.1
# 3  2021-04       119.3
# 4  2021-05       180.3
# 5  2021-06       168.5
# 6  2021-07       231.8
# 7  2021-08       224.5
# 8  2021-09       192.8
# 9  2021-10       122.9

# %%
import statsmodels.api as sm

# %%
df=data

# %%
df.head(10)
# Out:
#      Month  Sales(USD)
# 0  2021-01       266.0
# 1  2021-02       145.9
# 2  2021-03       183.1
# 3  2021-04       119.3
# 4  2021-05       180.3
# 5  2021-06       168.5
# 6  2021-07       231.8
# 7  2021-08       224.5
# 8  2021-09       192.8
# 9  2021-10       122.9

# %%
df=df.set_index('Month')

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima

# %%
df['first_diff']=df-df.shift(1)

# %%
size=int(len(df)*0.66)
train=df[:size]
test=df[size:]

# %%
auto_arima(df['first_diff'].dropna(),  trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=430.873, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=406.022, Time=0.18 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=409.013, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=429.229, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=403.628, Time=0.34 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=404.692, Time=0.57 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=404.286, Time=0.52 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=402.467, Time=0.32 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=401.529, Time=0.99 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.94 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.64 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 9.095 seconds
# ARIMA(order=(1, 0, 2), scoring_args={}, suppress_warnings=True)

# %%
model=ARIMA(train['first_diff'],order=(1, 0, 2))
result=model.fit()
result.summary()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             first_diff   No. Observations:                   23
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -121.724
# Date:                Thu, 25 Jan 2024   AIC                            253.447
# Time:                        08:20:22   BIC                            259.125
# Sample:                    01-01-2021   HQIC                           254.875
#                          - 11-01-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.4461      3.021      2.134      0.033       0.526      12.366
# ar.L1         -0.8589      0.348     -2.471      0.013      -1.540      -0.178
# ma.L1         -0.3401    101.297     -0.003      0.997    -198.878     198.198
# ma.L2         -0.6594     66.685     -0.010      0.992    -131.360     130.041
# sigma2      3180.8670   3.21e+05      0.010      0.992   -6.26e+05    6.32e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 1.97
# Prob(Q):                              0.63   Prob(JB):                         0.37
# Heteroskedasticity (H):               1.67   Skew:                             0.71
# Prob(H) (two-sided):                  0.48   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df['pred']=result.predict(start=len(train),end=len(df)-1)

# %%
df.tail(15)
# Out:
#          Sales(USD)  first_diff       pred
# Month
# 2022-10       421.6       131.7        NaN
# 2022-11       264.5      -157.1        NaN
# 2022-12       342.3        77.8  65.250619
# 2023-01       339.7        -2.6 -45.105676
# 2023-02       440.4       100.7  50.724354
# 2023-03       315.9      -124.5 -31.584904
# 2023-04       439.3       123.4  39.111244
# 2023-05       401.3       -38.0 -21.610302
# 2023-06       437.4        36.1  30.543969
# 2023-07       575.5       138.1 -14.251794
# 2023-08       407.6      -167.9  24.223682
# 2023-09       682.0       274.4  -8.823244
# 2023-10       475.3      -206.7  19.561053
# 2023-11       581.3       106.0  -4.818470
# 2023-12       646.9        65.6  16.121317

# %%
plt.plot(test['first_diff'],color='red')
plt.plot(df['pred'])

# %%
import numpy as np

# %%
from sklearn.metrics import mean_squared_error
rms = np.sqrt(mean_squared_error(test['first_diff'], df['pred'].dropna()))
rms
# Out:
# 132.0722435269656

# %%
print(df.index)
# Out:
# Index(['2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06',
#        '2021-07', '2021-08', '2021-09', '2021-10', '2021-11', '2021-12',
#        '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06',
#        '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12',
#        '2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06',
#        '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12'],
#       dtype='object', name='Month')

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = df.dropna()
df.head()
# Out:
#          Sales(USD)  first_diff       pred
# Month
# 2022-12       342.3        77.8  65.250619
# 2023-01       339.7        -2.6 -45.105676
# 2023-02       440.4       100.7  50.724354
# 2023-03       315.9      -124.5 -31.584904
# 2023-04       439.3       123.4  39.111244

# %%
df['predict']=df['Sales(USD)']+df['pred']
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16112\3845147257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predict']=df['Sales(USD)']+df['pred']
#          Sales(USD)  first_diff       pred     predict
# Month
# 2022-12       342.3        77.8  65.250619  407.550619
# 2023-01       339.7        -2.6 -45.105676  294.594324
# 2023-02       440.4       100.7  50.724354  491.124354
# 2023-03       315.9      -124.5 -31.584904  284.315096
# 2023-04       439.3       123.4  39.111244  478.411244

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
import numpy as np

# %%
rms = np.sqrt(mean_squared_error(df['predict'].dropna(),test['Sales(USD)']))
rms
# Out:
# 33.196222540385705

# %%
plt.plot(df['predict'],color='red')
plt.plot(test['Sales(USD)'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
